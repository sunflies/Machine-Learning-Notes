# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_dataset=pd.read_csv("C:\\Users\\ML LABS\\Downloads\\train (2).csv")

# %%
base_dataset.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
#
# [1 rows x 81 columns]

# %%
plt.hist(base_dataset['SalePrice'])
plt.show()
plt.hist(base_dataset['LotArea'])
# Out:
# (array([1.423e+03, 2.400e+01, 8.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([  1300. ,  22694.5,  44089. ,  65483.5,  86878. , 108272.5,
#         129667. , 151061.5, 172456. , 193850.5, 215245. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Findings
# <ul>
#     <li> Minimum House Price is arond 60000  </li>
#     <li> Maximum House Price is arond 700000 </li>
#     <li> Majority of the customers are purchasing between 100000 $,2,20000 $</li>
# </ul>

# %% [markdown]
# #### Insights
# <ul>
#     <li> The banks are offering loans in the range of 0.1M to 2.2 M . hence, Majority of the people are purchasing in the range </li>
#     <li> Average Household income is 0.1M to 2.2 M . Hence, Majoirty of the purchases are with in the range</li>
#
# </ul>

# %%
plt.hist(base_dataset['SalePrice'],color='r')
plt.xlabel('Sale price of a house')
plt.ylabel(" Count of Number of customers purchased house")
# Out:
# Text(0, 0.5, ' Count of Number of customers purchased house')

# %%
plt.hist(base_dataset['SalePrice'],color='b')
plt.xlabel('Sale price of a house')
plt.ylabel(" Count of Number of customers purchased house")
plt.xlim(0,300000)
plt.ylim(0,600)
# Out:
# (0, 600)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.hist(base_dataset['SalePrice'],color='b')
plt.subplot(2,2,2)
plt.hist(base_dataset['SalePrice'],color='r')
plt.subplot(2,2,3)
plt.hist(base_dataset['SalePrice'],color='g')
plt.subplot(2,2,4)
plt.hist(base_dataset['SalePrice'],color='y')
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %%
base_dataset['SalePrice'][0:10].values
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000,
#        129900, 118000], dtype=int64)

# %%
plt.plot(base_dataset['SalePrice'][0:10].values,color='r')
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')

# %%
plt.plot(base_dataset['SalePrice'][0:10].values,color='r',linewidth=10,alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')

# %%
plt.plot(base_dataset['SalePrice'][0:10].values,color='r',linewidth=2)
plt.plot(base_dataset['SalePrice'][10:20].values,color='b',linewidth=2)
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')

# %%
plt.figure(figsize=(20,5))
plt.plot(base_dataset['SalePrice'][0:10].values,color='r',linewidth=2)
plt.plot(base_dataset['SalePrice'][10:20].values,color='b',linewidth=2)
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')

# %%
plt.figure(figsize=(20,5))
plt.plot(base_dataset['SalePrice'][0:10],color='r',linewidth=2)
plt.plot(base_dataset['SalePrice'][10:20],color='b',linewidth=2)
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')

# %%
plt.figure(figsize=(20,5))
plt.plot(base_dataset['SalePrice'][0:10],color='y',linewidth=2,marker='o',markersize=5,markeredgecolor='r',markeredgewidth=20)
plt.plot(base_dataset['SalePrice'][10:20],color='b',linewidth=2,marker='o',markersize=15,markeredgecolor='r',markerfacecolor='w')
plt.xlabel("Days")
plt.ylabel("Sale Price")
plt.title("Days vs Sale Price")
# Out:
# Text(0.5, 1.0, 'Days vs Sale Price')
