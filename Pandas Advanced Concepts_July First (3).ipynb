# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
base_dataset=sns.load_dataset("titanic")

# %%
base_dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
base_dataset.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
base_dataset.columns.tolist()
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
base_dataset['age'].argmax()
# Out:
# 630

# %%
base_dataset.iloc[[base_dataset['age'].argmax()]]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.0        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True

# %%
for index, row in base_dataset.iterrows():
    print (row)
    if index == 2:
        break
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                     22
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
# survived               1
# pclass                 1
# sex               female
# age                   38
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object
# survived                 1
# pclass                   3
# sex                 female
# ...

# %%
import pandas as pd
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %%
pd.crosstab(base_dataset.sex,base_dataset.parch)
# Out:
# parch     0   1   2  3  4  5  6
# sex
# female  194  60  49  4  2  4  1
# male    484  58  31  1  2  1  0

# %%
base_dataset.pivot_table('age',index='sex',columns='survived')
# Out:
# survived          0          1
# sex
# female    25.046875  28.847716
# male      31.618056  27.276022

# %%
base_dataset.sex.str.replace("ma",'xyz').head()
# Out:
# 0      xyzle
# 1    fexyzle
# 2    fexyzle
# 3    fexyzle
# 4      xyzle
# Name: sex, dtype: object

# %%
base_dataset=base_dataset[['age','fare','sex']]

# %%
import numpy as np
base_dataset.groupby(['sex']).agg([np.mean, np.std, np.min,np.max])
# Out:
#               age                              fare
#              mean        std  amin  amax       mean        std  amin      amax
# sex
# female  27.915709  14.110146  0.75  63.0  44.479818  57.997698  6.75  512.3292
# male    30.726645  14.678201  0.42  80.0  25.523893  43.138263  0.00  512.3292

# %% [markdown]
# ### String Functions

# %%
base_dataset['sex'].str.swapcase().head()
# Out:
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 3    FEMALE
# 4      MALE
# Name: sex, dtype: object

# %%
base_dataset['sex'].str.lower().head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
base_dataset['sex'].str.upper().head()
# Out:
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 3    FEMALE
# 4      MALE
# Name: sex, dtype: object

# %%
base_dataset['sex'].str.split("m").head()
# Out:
# 0      [, ale]
# 1    [fe, ale]
# 2    [fe, ale]
# 3    [fe, ale]
# 4      [, ale]
# Name: sex, dtype: object

# %%
base_dataset['sex'].head(2)
# Out:
# 0      male
# 1    female
# Name: sex, dtype: object

# %%
base_dataset['sex'].str.cat(sep=',')[0:20]
# Out:
# 'male,female,female,f'

# %%
base_dataset.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
for index, row in base_dataset.iterrows():
    print (row.pclass)
    if index==2:
        break
# Out:
# 3
# 1
# 3

# %%
base_dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
for index, row in base_dataset.iteritems():
    print(row)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
# 5      3
# 6      1
# 7      3
# 8      3
# 9      2
# 10     3
# 11     1
# 12     3
# 13     3
# 14     3
# 15     2
# 16     3
# 17     2
# 18     3
# 19     3
# 20     2
# 21     2
# 22     3
# 23     1
# 24     3
# ...
